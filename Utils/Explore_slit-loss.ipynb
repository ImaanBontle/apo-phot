# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt

# %matplotlib widget

data_v1_2773 = np.loadtxt("../../SharedData/pathlosses_deep_R100/R100_v1/p01/pathlosses_correction_deep_hst_1x1_p01_exp00_idcat002773_v1.txt").transpose()
data_v1_2773_points = np.loadtxt("../../SharedData/pathlosses_deep_R100/R100_v1/p01/pathlosses_correction_deep_hst_1x1_p01_exp00_idcat002773_v1_point.txt").transpose()
data_v0_2773 = np.loadtxt("../../SharedData/pathlosses_deep_R100/R100_v0/p01/pathlosses_correction_deep_hst_1x1_p01_exp00_idcat002773_v0.txt").transpose()
data_v0_2773_points = np.loadtxt("../../SharedData/pathlosses_deep_R100/R100_v0/p01/pathlosses_correction_deep_hst_1x1_p01_exp00_idcat002773_v0_point.txt").transpose()

# %%
plt.close("all")

plt.plot(data_v1_2773[1], data_v1_2773[0])
plt.plot(data_v1_2773_points[1], data_v1_2773_points[0])
plt.plot(data_v0_2773[1], data_v0_2773[0])
plt.plot(data_v0_2773_points[1], data_v0_2773_points[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
